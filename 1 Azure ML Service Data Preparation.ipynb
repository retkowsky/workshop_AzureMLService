# %% [markdown]
# # 1. Préparation des données avec Azure ML Services

# %% [markdown]
# #### Note: Some features in this Notebook will _not_ work with the Private Preview version of the SDK; it assumes the Public Preview version.
#
# Wonder how you can make the most of the Azure ML Data Prep SDK? In this "Getting Started" guide, we'll showcase a few highlights that make this SDK shine for big datasets where `pandas` and `dplyr` can fall short. Using the [Ford GoBike dataset](https://www.fordgobike.com/system-data) as an example, we'll cover how to build Dataflows that allow you to:

# %% [markdown]
# ## 1.1 Informations

# %%
import sys
sys.version
# Out:
# '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 17:14:51) \n[GCC 7.2.0]'

# %%
# !pip install azureml
# Out:
# Requirement already satisfied: azureml in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (0.2.7)
# Requirement already satisfied: pandas in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml) (0.22.0)
# Requirement already satisfied: python-dateutil in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml) (2.7.3)
# Requirement already satisfied: requests in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml) (2.19.1)
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas->azureml) (2018.5)
# Requirement already satisfied: numpy>=1.9.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas->azureml) (1.14.5)
# Requirement already satisfied: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil->azureml) (1.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->azureml) (2018.8.24)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->azureml) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->azureml) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from requests->azureml) (2.7)

# %%
import azureml.core
print("SDK Version:", azureml.core.VERSION)
# Out:
# SDK Version: 0.1.74

# %%
from IPython.display import display
from os import path
from tempfile import mkdtemp

import pandas as pd
import azureml.dataprep as dprep

# %% [markdown]
# ## 2. Importation des données
#
# Azure ML Data Prep supports many different file reading formats (i.e. CSV, Excel, Parquet), and also offers the ability to infer column types automatically.

# %%
gobike = dprep.read_csv(path='https://dprepdata.blob.core.windows.net/demo/ford_gobike/2017-fordgobike-tripdata.csv')
gobike.head(11)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1         78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2         45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3         62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4         43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
# 5          9226  2017-12-31 22:51:00.9180  2018-01-01 01:24:47.1660
# 6          4507  2017-12-31 23:49:28.4220  2018-01-01 01:04:35.6190
# 7          4334  2017-12-31 23:46:37.1960  2018-01-01 00:58:51.2110
# 8          4150  2017-12-31 23:37:07.5480  2018-01-01 00:46:18.3080
# 9          4238  2017-12-31 23:35:38.1450  2018-01-01 00:46:17.0530
# 10         3292  2017-12-31 23:46:32.4030  2018-01-01 00:41:24.6050
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
# 5                30     San Francisco Caltrain (Townsend St at 4th St)
# 6               259                            Addison St at Fourth St
# 7               284  Yerba Buena Center for the Arts (Howard St at ...
# 8                20    Mechanics Monument Plaza (Market St at Bush St)
# 9                20    Mechanics Monument Plaza (Market St at Bush St)
# 10              284  Yerba Buena Center for the Arts (Howard St at ...
#
#    start_station_latitude start_station_longitude end_station_id  \
# 0      37.776434819204745     -122.42624402046204             43
# 1       37.78487208436062     -122.40087568759917             96
# 2              37.8703477            -122.2677637            245
# 3       37.77452040113685      -122.4094493687153              5
# 4              37.8688126             -122.258764            247
# 5               37.776598             -122.395282             30
# 6               37.866249            -122.2993708            259
# 7       37.78487208436062     -122.40087568759917            284
# 8                 37.7913             -122.399051             20
# 9                 37.7913             -122.399051             20
# 10      37.78487208436062     -122.40087568759917             22
#
#                                      end_station_name end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1                               Dolores St at 15th St           37.7662102
# 2                              Downtown Berkeley BART           37.8703477
# 3        Powell St BART Station (Market St at 5th St)   37.783899357084934
# 4                           Fulton St at Bancroft Way           37.8677892
# 5      San Francisco Caltrain (Townsend St at 4th St)            37.776598
# 6                             Addison St at Fourth St            37.866249
# 7   Yerba Buena Center for the Arts (Howard St at ...    37.78487208436062
# 8     Mechanics Monument Plaza (Market St at Bush St)              37.7913
# 9     Mechanics Monument Plaza (Market St at Bush St)              37.7913
# 10                              Howard St at Beale St            37.789756
#
#    end_station_longitude bike_id   user_type member_birth_year member_gender
# 0           -122.4159292      96    Customer              1987          Male
# 1           -122.4266136      88    Customer              1965        Female
# 2           -122.2677637    1094    Customer
# 3    -122.40844488143921    2831    Customer
# 4           -122.2658964    3167  Subscriber              1997        Female
# 5            -122.395282    1487    Customer
# 6           -122.2993708    3539    Customer              1991        Female
# 7    -122.40087568759917    1503    Customer
# 8            -122.399051    3125    Customer
# 9            -122.399051    2543    Customer
# 10           -122.394643    3058    Customer

# %% [markdown]
# In order to iterate more quickly, we can take a sample of our data. Later, we can then apply the same transformations to the entire dataset.

# %%
sampled_gobike = gobike.take_sample(probability=0.01, seed=5)

# %% [markdown]
# ## 3. Audit des données
#
# Let's understand what our data looks like. Azure ML Data Prep facilitates this process by offering data profiles that help us glimpse into column types and column summary statistics.

# %%
# Audit sur l'ensemble des données
#gobike.get_profile()

# %%
# Audit sur l'échentillon
sampled_gobike.get_profile()
# Out:
# ColumnProfile
#     name: duration_sec
#     type: FieldType.STRING
#
#     min: 1000
#     max: 997
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: start_time
#     type: FieldType.STRING
#
#     min: 2017-06-28 13:48:12.3890
#     max: 2017-12-31 23:55:09.6860
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: end_time
#     type: FieldType.STRING
#
#     min: 2017-06-28 14:00:04.9250
#     max: 2018-01-01 15:12:50.2450
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: start_station_id
#     type: FieldType.STRING
#
#     min: 10
#     max: 99
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: start_station_name
#     type: FieldType.STRING
#
#     min: 10th Ave at E 15th St
#     max: Yerba Buena Center for the Arts (Howard St at 3rd St)
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: start_station_latitude
#     type: FieldType.STRING
#
#     min: 37.3229796
#     max: 37.88022244590679
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: start_station_longitude
#     type: FieldType.STRING
#
#     min: -121.8766132
#     max: -122.44429260492325
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: end_station_id
#     type: FieldType.STRING
#
#     min: 10
#     max: 99
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: end_station_name
#     type: FieldType.STRING
#
#     min: 10th Ave at E 15th St
#     max: Yerba Buena Center for the Arts (Howard St at 3rd St)
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: end_station_latitude
#     type: FieldType.STRING
#
#     min: 37.3229796
#     max: 37.8740141
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: end_station_longitude
#     type: FieldType.STRING
#
#     min: -121.8759263
#     max: -122.44429260492325
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: bike_id
#     type: FieldType.STRING
#
#     min: 100
#     max: 999
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: user_type
#     type: FieldType.STRING
#
#     min: Customer
#     max: Subscriber
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: member_birth_year
#     type: FieldType.STRING
#
#     min:
#     max: 1999
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0
#
# ColumnProfile
#     name: member_gender
#     type: FieldType.STRING
#
#     min:
#     max: Other
#     count: 5268.0
#     missing_count: 0.0
#     error_count: 0.0

# %% [markdown]
# It appears that we have quite a few missing values in `member_birth_year`. We also immediately see that we have some empty strings in our `member_gender` column. With the data profiler, we can quickly do a sanity check on our dataset and see where we might need to start data cleaning.

# %% [markdown]
# ## 4. Transformation des données par l'exemple
#
# Azure ML Data Prep comes with additional "smart" transforms created by Microsoft Research. Here, we'll look at how you can derive a new column by providing examples of input-output pairs. Rather than explicitly using regular expressions to extract dates or hours from datetimes, we can provide examples for Azure ML Data Prep to learn what the pattern is. In fact, these smart transformations can also handle more complex derivations like inferring the day of the week from datetimes.

# %%
sgb_derived = sampled_gobike\
    .to_string(
        columns=['start_time', 'end_time']
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='date',
        example_data=[('2017-12-31 16:57:39.6540', '2017-12-31'), ('2017-12-31 16:57:39', '2017-12-31')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='hour',
        example_data=[('2017-12-31 16:57:39.6540', '16')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='wday',
        example_data=[('2017-12-31 16:57:39.6540', 'Sunday')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='day',
        example_data=[('2017-12-31 16:57:39.6540', '31')]
    )\
      .derive_column_by_example(
        source_columns='start_time',
        new_column_name='month',
        example_data=[('2017-12-31 16:57:39.6540', '12')]
    )

# %%
sgb_derived.filter(dprep.col('wday') != 'Sunday').head(11)
# Out:
#    duration_sec                start_time month day      wday hour  \
# 0           572  2017-12-30 18:19:05.7310    12  30  Saturday   18
# 1           821  2017-12-30 18:13:05.1240    12  30  Saturday   18
# 2          2789  2017-12-30 15:52:21.2220    12  30  Saturday   15
# 3          1380  2017-12-30 16:07:44.1080    12  30  Saturday   16
# 4           198  2017-12-30 16:23:49.0310    12  30  Saturday   16
# 5           463  2017-12-30 15:43:11.5520    12  30  Saturday   15
# 6          1334  2017-12-30 14:21:05.3330    12  30  Saturday   14
# 7           603  2017-12-30 14:15:40.5830    12  30  Saturday   14
# 8           858  2017-12-30 13:52:14.7550    12  30  Saturday   13
# 9          1720  2017-12-30 12:13:24.1740    12  30  Saturday   12
# 10          370  2017-12-30 11:45:33.2780    12  30  Saturday   11
#
#           date                  end_time start_station_id  \
# 0   2017-12-30  2017-12-30 18:28:37.8250              323
# 1   2017-12-30  2017-12-30 18:26:46.3650              317
# 2   2017-12-30  2017-12-30 16:38:50.4270              121
# 3   2017-12-30  2017-12-30 16:30:44.9010              239
# 4   2017-12-30  2017-12-30 16:27:07.7230               76
# 5   2017-12-30  2017-12-30 15:50:55.0040              324
# 6   2017-12-30  2017-12-30 14:43:20.0360               85
# 7   2017-12-30  2017-12-30 14:25:43.7850                6
# 8   2017-12-30  2017-12-30 14:06:32.9160               60
# 9   2017-12-30  2017-12-30 12:42:04.3660                6
# 10  2017-12-30  2017-12-30 11:51:44.1820              197
#
#                      start_station_name start_station_latitude  \
# 0                    Broadway at Kearny      37.79801364395978
# 1             San Salvador St at 9th St              37.333955
# 2                    Mission Playground             37.7592103
# 3         Bancroft Way at Telegraph Ave             37.8688126
# 4            McCoppin St at Valencia St      37.77166246221617
# 5   Union Square (Powell St at Post St)     37.788299978150825
# 6               Church St at Duboce Ave             37.7700831
# 7         The Embarcadero at Sansome St               37.80477
# 8                  8th St at Ringold St      37.77452040113685
# 9         The Embarcadero at Sansome St               37.80477
# 10          El Embarcadero at Grand Ave             37.8088479
#
#    start_station_longitude end_station_id  \
# 0      -122.40595042705534             15
# 1              -121.877349            304
# 2             -122.4213392            120
# 3              -122.258764            241
# 4      -122.42242321372034             76
# 5      -122.40853071212767             44
# 6             -122.4291557             17
# 7              -122.403234            323
# 8       -122.4094493687153             36
# 9              -122.403234             99
# 10            -122.2496799            200
#
#                                      end_station_name end_station_latitude  \
# 0   San Francisco Ferry Building (Harry Bridges Pl...            37.795392
# 1                                Jackson St at 5th St     37.3487586867448
# 2                                Mission Dolores Park           37.7614205
# 3                                  Ashby BART Station           37.8524766
# 4                          McCoppin St at Valencia St    37.77166246221617
# 5   Civic Center/UN Plaza BART Station (Market St ...           37.7810737
# 6    Embarcadero BART Station (Beale St at Market St)            37.792251
# 7                                  Broadway at Kearny    37.79801364395978
# 8                                 Folsom St at 3rd St             37.78383
# 9                                Folsom St at 15th St           37.7670373
# 10                               2nd Ave at E 18th St   37.800213566969795
#
#    end_station_longitude bike_id   user_type member_birth_year member_gender
# 0            -122.394203    3033    Customer              1996          Male
# 1    -121.89479783177376    2533  Subscriber              1970          Male
# 2           -122.4264353    1837    Customer
# 3           -122.2702132    1297    Customer
# 4    -122.42242321372034     364    Customer
# 5           -122.4117382     762  Subscriber              1991        Female
# 6            -122.397086     974    Customer
# 7    -122.40595042705534    2359    Customer
# 8             -122.39887     276    Customer
# 9           -122.4154425     617    Customer              1972        Female
# 10   -122.25381016731262    1545  Subscriber              1974        Female

# %% [markdown]
# We can also filter on other column types; let's take a peek at rides that lasted over 5 hours.

# %%
sgb_derived.filter(dprep.col('duration_sec') > (60 * 60 * 5)).head(11)
# Out:
#    duration_sec                start_time month day    wday hour        date  \
# 0         80110  2017-12-31 16:57:39.6540    12  31  Sunday   16  2017-12-31
# 1          1397  2017-12-31 23:55:09.6860    12  31  Sunday   23  2017-12-31
# 2          2511  2017-12-31 22:58:26.5240    12  31  Sunday   22  2017-12-31
# 3           901  2017-12-31 22:17:39.9100    12  31  Sunday   22  2017-12-31
# 4           853  2017-12-31 21:22:37.6430    12  31  Sunday   21  2017-12-31
# 5           189  2017-12-31 20:48:37.4920    12  31  Sunday   20  2017-12-31
# 6          1208  2017-12-31 19:56:43.3940    12  31  Sunday   19  2017-12-31
# 7           426  2017-12-31 17:11:48.3310    12  31  Sunday   17  2017-12-31
# 8           962  2017-12-31 16:57:20.9300    12  31  Sunday   16  2017-12-31
# 9           204  2017-12-31 15:26:41.6630    12  31  Sunday   15  2017-12-31
# 10          819  2017-12-31 15:06:20.1730    12  31  Sunday   15  2017-12-31
#
#                     end_time start_station_id  \
# 0   2018-01-01 15:12:50.2450               74
# 1   2018-01-01 00:18:26.7210               78
# 2   2017-12-31 23:40:17.9870               30
# 3   2017-12-31 22:32:41.6300               66
# 4   2017-12-31 21:36:51.1790               14
# 5   2017-12-31 20:51:46.6580               37
# 6   2017-12-31 20:16:51.5510               13
# 7   2017-12-31 17:18:55.0010              123
# 8   2017-12-31 17:13:23.5600              176
# 9   2017-12-31 15:30:06.1460               86
# 10  2017-12-31 15:19:59.8640               81
#
#                                 start_station_name start_station_latitude  \
# 0                            Laguna St at Hayes St     37.776434819204745
# 1                              Folsom St at 9th St             37.7737172
# 2   San Francisco Caltrain (Townsend St at 4th St)              37.776598
# 3                            3rd St at Townsend St      37.77874161153677
# 4                            Clay St at Battery St              37.795001
# 5                              2nd St at Folsom St      37.78499972833808
# 6                   Commercial St at Montgomery St              37.794231
# 7                             Folsom St at 19th St             37.7605936
# 8                           MacArthur BART Station      37.82840997305853
# 9                          Market St at Dolores St             37.7693053
# 10                              Berry St at 4th St               37.77588
#
#    start_station_longitude end_station_id  \
# 0      -122.42624402046204             43
# 1             -122.4116467             15
# 2              -122.395282              6
# 3      -122.39274082710836             23
# 4               -122.39997              8
# 5      -122.39593561749642             48
# 6              -122.402923              6
# 7             -122.4148171            134
# 8      -122.26631462574005            231
# 9             -122.4268256             95
# 10              -122.39317             15
#
#                                      end_station_name end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1   San Francisco Ferry Building (Harry Bridges Pl...            37.795392
# 2                       The Embarcadero at Sansome St             37.80477
# 3                       The Embarcadero at Steuart St            37.791464
# 4                       The Embarcadero at Vallejo St            37.799953
# 5                                 2nd St at S Park St   37.782411189735896
# 6                       The Embarcadero at Sansome St             37.80477
# 7                              Valencia St at 24th St           37.7524278
# 8                               14th St at Filbert St    37.80874983465997
# 9                               Sanchez St at 15th St           37.7662185
# 10  San Francisco Ferry Building (Harry Bridges Pl...            37.795392
#
#    end_station_longitude bike_id   user_type member_birth_year member_gender
# 0           -122.4159292      96    Customer              1987          Male
# 1            -122.394203    1667    Customer
# 2            -122.403234    3329    Customer
# 3            -122.391034    3569    Customer
# 4            -122.398525     101    Customer
# 5    -122.39270595839115    1056    Customer              1988          Male
# 6            -122.403234    2736  Subscriber              1994          Male
# 7           -122.4206278    2256  Subscriber              1991          Male
# 8    -122.28328227996825     305    Customer
# 9           -122.4310597    2183  Subscriber              1992          Male
# 10           -122.394203     464    Customer              1994        Female

# %% [markdown]
# ## 5. Transformation des données
#
# In addition to "smart" transformations, Azure ML Data Prep also supports many common data science transforms familiar to other industry-standard data science libraries. Here, we'll explore the ability to `summarize` and `replace`. We'll also get to use `join` when we handle assertions.
#
# #### Agrégation

# %% [markdown]
# Azure Data Prep also makes it easy to append this output of `summarize` to the original table based on the grouping variable.

# %%
sgb_appended = sgb_derived\
    .summarize(
        summary_columns=[
            dprep\
                .SummaryColumnsValue(
                    column_id='duration_sec', 
                    summary_column_name='duration_sec_mean', 
                    summary_function=dprep.SummaryFunction.MEAN
                )
        ],
        group_by_columns=['date'],
        join_back=True
    )
sgb_appended.head(11)
# Out:
#    duration_sec                start_time month day    wday hour        date  \
# 0         80110  2017-12-31 16:57:39.6540    12  31  Sunday   16  2017-12-31
# 1          1397  2017-12-31 23:55:09.6860    12  31  Sunday   23  2017-12-31
# 2          2511  2017-12-31 22:58:26.5240    12  31  Sunday   22  2017-12-31
# 3           901  2017-12-31 22:17:39.9100    12  31  Sunday   22  2017-12-31
# 4           853  2017-12-31 21:22:37.6430    12  31  Sunday   21  2017-12-31
# 5           189  2017-12-31 20:48:37.4920    12  31  Sunday   20  2017-12-31
# 6          1208  2017-12-31 19:56:43.3940    12  31  Sunday   19  2017-12-31
# 7           426  2017-12-31 17:11:48.3310    12  31  Sunday   17  2017-12-31
# 8           962  2017-12-31 16:57:20.9300    12  31  Sunday   16  2017-12-31
# 9           204  2017-12-31 15:26:41.6630    12  31  Sunday   15  2017-12-31
# 10          819  2017-12-31 15:06:20.1730    12  31  Sunday   15  2017-12-31
#
#                     end_time start_station_id  \
# 0   2018-01-01 15:12:50.2450               74
# 1   2018-01-01 00:18:26.7210               78
# 2   2017-12-31 23:40:17.9870               30
# 3   2017-12-31 22:32:41.6300               66
# 4   2017-12-31 21:36:51.1790               14
# 5   2017-12-31 20:51:46.6580               37
# 6   2017-12-31 20:16:51.5510               13
# 7   2017-12-31 17:18:55.0010              123
# 8   2017-12-31 17:13:23.5600              176
# 9   2017-12-31 15:30:06.1460               86
# 10  2017-12-31 15:19:59.8640               81
#
#                                 start_station_name  \
# 0                            Laguna St at Hayes St
# 1                              Folsom St at 9th St
# 2   San Francisco Caltrain (Townsend St at 4th St)
# 3                            3rd St at Townsend St
# 4                            Clay St at Battery St
# 5                              2nd St at Folsom St
# 6                   Commercial St at Montgomery St
# 7                             Folsom St at 19th St
# 8                           MacArthur BART Station
# 9                          Market St at Dolores St
# 10                              Berry St at 4th St
#
#                           ...                         start_station_longitude  \
# 0                         ...                             -122.42624402046204
# 1                         ...                                    -122.4116467
# 2                         ...                                     -122.395282
# 3                         ...                             -122.39274082710836
# 4                         ...                                      -122.39997
# 5                         ...                             -122.39593561749642
# 6                         ...                                     -122.402923
# 7                         ...                                    -122.4148171
# 8                         ...                             -122.26631462574005
# 9                         ...                                    -122.4268256
# 10                        ...                                      -122.39317
#
#    end_station_id                                   end_station_name  \
# 0              43  San Francisco Public Library (Grove St at Hyde...
# 1              15  San Francisco Ferry Building (Harry Bridges Pl...
# 2               6                      The Embarcadero at Sansome St
# 3              23                      The Embarcadero at Steuart St
# 4               8                      The Embarcadero at Vallejo St
# 5              48                                2nd St at S Park St
# 6               6                      The Embarcadero at Sansome St
# 7             134                             Valencia St at 24th St
# 8             231                              14th St at Filbert St
# 9              95                              Sanchez St at 15th St
# 10             15  San Francisco Ferry Building (Harry Bridges Pl...
#
#    end_station_latitude end_station_longitude bike_id   user_type  \
# 0            37.7787677          -122.4159292      96    Customer
# 1             37.795392           -122.394203    1667    Customer
# 2              37.80477           -122.403234    3329    Customer
# 3             37.791464           -122.391034    3569    Customer
# 4             37.799953           -122.398525     101    Customer
# 5    37.782411189735896   -122.39270595839115    1056    Customer
# 6              37.80477           -122.403234    2736  Subscriber
# 7            37.7524278          -122.4206278    2256  Subscriber
# 8     37.80874983465997   -122.28328227996825     305    Customer
# 9            37.7662185          -122.4310597    2183  Subscriber
# 10            37.795392           -122.394203     464    Customer
#
#    member_birth_year member_gender  \
# 0               1987          Male
# 1
# 2
# 3
# 4
# 5               1988          Male
# 6               1994          Male
# 7               1991          Male
# 8
# 9               1992          Male
# 10              1994        Female
#
#                                     duration_sec_mean
# 0   azureml.dataprep.native.DataPrepError("'Cannot...
# 1   azureml.dataprep.native.DataPrepError("'Cannot...
# 2   azureml.dataprep.native.DataPrepError("'Cannot...
# 3   azureml.dataprep.native.DataPrepError("'Cannot...
# 4   azureml.dataprep.native.DataPrepError("'Cannot...
# 5   azureml.dataprep.native.DataPrepError("'Cannot...
# 6   azureml.dataprep.native.DataPrepError("'Cannot...
# 7   azureml.dataprep.native.DataPrepError("'Cannot...
# 8   azureml.dataprep.native.DataPrepError("'Cannot...
# 9   azureml.dataprep.native.DataPrepError("'Cannot...
# 10  azureml.dataprep.native.DataPrepError("'Cannot...
#
# [11 rows x 21 columns]

# %% [markdown]
# #### Remplacement des valeurs manquantes
#
# Recall that our `member_gender` column had empty strings that stood in place of `None`. Let's use our `replace` function to properly recode them as `None`s.

# %%
sgb_replaced = sampled_gobike.replace_na(columns=['member_gender'])
sgb_replaced.head(11)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1          1397  2017-12-31 23:55:09.6860  2018-01-01 00:18:26.7210
# 2          2511  2017-12-31 22:58:26.5240  2017-12-31 23:40:17.9870
# 3           901  2017-12-31 22:17:39.9100  2017-12-31 22:32:41.6300
# 4           853  2017-12-31 21:22:37.6430  2017-12-31 21:36:51.1790
# 5           189  2017-12-31 20:48:37.4920  2017-12-31 20:51:46.6580
# 6          1208  2017-12-31 19:56:43.3940  2017-12-31 20:16:51.5510
# 7           426  2017-12-31 17:11:48.3310  2017-12-31 17:18:55.0010
# 8           962  2017-12-31 16:57:20.9300  2017-12-31 17:13:23.5600
# 9           204  2017-12-31 15:26:41.6630  2017-12-31 15:30:06.1460
# 10          819  2017-12-31 15:06:20.1730  2017-12-31 15:19:59.8640
#
#    start_station_id                              start_station_name  \
# 0                74                           Laguna St at Hayes St
# 1                78                             Folsom St at 9th St
# 2                30  San Francisco Caltrain (Townsend St at 4th St)
# 3                66                           3rd St at Townsend St
# 4                14                           Clay St at Battery St
# 5                37                             2nd St at Folsom St
# 6                13                  Commercial St at Montgomery St
# 7               123                            Folsom St at 19th St
# 8               176                          MacArthur BART Station
# 9                86                         Market St at Dolores St
# 10               81                              Berry St at 4th St
#
#    start_station_latitude start_station_longitude end_station_id  \
# 0      37.776434819204745     -122.42624402046204             43
# 1              37.7737172            -122.4116467             15
# 2               37.776598             -122.395282              6
# 3       37.77874161153677     -122.39274082710836             23
# 4               37.795001              -122.39997              8
# 5       37.78499972833808     -122.39593561749642             48
# 6               37.794231             -122.402923              6
# 7              37.7605936            -122.4148171            134
# 8       37.82840997305853     -122.26631462574005            231
# 9              37.7693053            -122.4268256             95
# 10               37.77588              -122.39317             15
#
#                                      end_station_name end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1   San Francisco Ferry Building (Harry Bridges Pl...            37.795392
# 2                       The Embarcadero at Sansome St             37.80477
# 3                       The Embarcadero at Steuart St            37.791464
# 4                       The Embarcadero at Vallejo St            37.799953
# 5                                 2nd St at S Park St   37.782411189735896
# 6                       The Embarcadero at Sansome St             37.80477
# 7                              Valencia St at 24th St           37.7524278
# 8                               14th St at Filbert St    37.80874983465997
# 9                               Sanchez St at 15th St           37.7662185
# 10  San Francisco Ferry Building (Harry Bridges Pl...            37.795392
#
#    end_station_longitude bike_id   user_type member_birth_year member_gender
# 0           -122.4159292      96    Customer              1987          Male
# 1            -122.394203    1667    Customer                            None
# 2            -122.403234    3329    Customer                            None
# 3            -122.391034    3569    Customer                            None
# 4            -122.398525     101    Customer                            None
# 5    -122.39270595839115    1056    Customer              1988          Male
# 6            -122.403234    2736  Subscriber              1994          Male
# 7           -122.4206278    2256  Subscriber              1991          Male
# 8    -122.28328227996825     305    Customer                            None
# 9           -122.4310597    2183  Subscriber              1992          Male
# 10           -122.394203     464    Customer              1994        Female

# %% [markdown]
# ## Assert on invalid data

# %%
gb_asserted = gobike\
    .assert_value(
        columns='member_birth_year', 
        expression=dprep.f_or(dprep.value.is_null(), dprep.value <= 1920),
        error_code='InvalidDate'
    )

# %% [markdown]
# Now, we can filter to see what caused the errors above:

# %%
gb_errors = gb_asserted.filter(dprep.col('member_birth_year').is_error())
gb_errors.head(5)
# Out:
#   duration_sec                start_time                  end_time  \
# 0        80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1        78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2        45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3        62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4        43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
#
#   start_station_id                                 start_station_name  \
# 0               74                              Laguna St at Hayes St
# 1              284  Yerba Buena Center for the Arts (Howard St at ...
# 2              245                             Downtown Berkeley BART
# 3               60                               8th St at Ringold St
# 4              239                      Bancroft Way at Telegraph Ave
#
#   start_station_latitude start_station_longitude end_station_id  \
# 0     37.776434819204745     -122.42624402046204             43
# 1      37.78487208436062     -122.40087568759917             96
# 2             37.8703477            -122.2677637            245
# 3      37.77452040113685      -122.4094493687153              5
# 4             37.8688126             -122.258764            247
#
#                                     end_station_name end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...           37.7787677
# 1                              Dolores St at 15th St           37.7662102
# 2                             Downtown Berkeley BART           37.8703477
# 3       Powell St BART Station (Market St at 5th St)   37.783899357084934
# 4                          Fulton St at Bancroft Way           37.8677892
#
#   end_station_longitude bike_id   user_type  \
# 0          -122.4159292      96    Customer
# 1          -122.4266136      88    Customer
# 2          -122.2677637    1094    Customer
# 3   -122.40844488143921    2831    Customer
# 4          -122.2658964    3167  Subscriber
#
#                                    member_birth_year member_gender
# 0  azureml.dataprep.native.DataPrepError("'Invali...          Male
# 1  azureml.dataprep.native.DataPrepError("'Invali...        Female
# 2  azureml.dataprep.native.DataPrepError("'Invali...
# 3  azureml.dataprep.native.DataPrepError("'Invali...
# 4  azureml.dataprep.native.DataPrepError("'Invali...        Female

# %% [markdown]
# #### Jointure
# But what were the original values? Let's use `join` to figure out what the values were that caused our assert to throw an error.

# %%
gb_errors.join(
    left_dataflow=gb_errors,
    right_dataflow=gobike,
    join_key_pairs=[
        ('duration_sec', 'duration_sec'),
        ('start_station_id', 'start_station_id'),
        ('bike_id', 'bike_id')
    ]
).head(11)
# Out:
#    l_duration_sec              l_start_time                l_end_time  \
# 0           80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1           78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2           45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3           62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4           43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
# 5            9226  2017-12-31 22:51:00.9180  2018-01-01 01:24:47.1660
# 6            4507  2017-12-31 23:49:28.4220  2018-01-01 01:04:35.6190
# 7            4334  2017-12-31 23:46:37.1960  2018-01-01 00:58:51.2110
# 8            4150  2017-12-31 23:37:07.5480  2018-01-01 00:46:18.3080
# 9            4238  2017-12-31 23:35:38.1450  2018-01-01 00:46:17.0530
# 10           3292  2017-12-31 23:46:32.4030  2018-01-01 00:41:24.6050
#
#    l_start_station_id                               l_start_station_name  \
# 0                  74                              Laguna St at Hayes St
# 1                 284  Yerba Buena Center for the Arts (Howard St at ...
# 2                 245                             Downtown Berkeley BART
# 3                  60                               8th St at Ringold St
# 4                 239                      Bancroft Way at Telegraph Ave
# 5                  30     San Francisco Caltrain (Townsend St at 4th St)
# 6                 259                            Addison St at Fourth St
# 7                 284  Yerba Buena Center for the Arts (Howard St at ...
# 8                  20    Mechanics Monument Plaza (Market St at Bush St)
# 9                  20    Mechanics Monument Plaza (Market St at Bush St)
# 10                284  Yerba Buena Center for the Arts (Howard St at ...
#
#    l_start_station_latitude l_start_station_longitude l_end_station_id  \
# 0        37.776434819204745       -122.42624402046204               43
# 1         37.78487208436062       -122.40087568759917               96
# 2                37.8703477              -122.2677637              245
# 3         37.77452040113685        -122.4094493687153                5
# 4                37.8688126               -122.258764              247
# 5                 37.776598               -122.395282               30
# 6                 37.866249              -122.2993708              259
# 7         37.78487208436062       -122.40087568759917              284
# 8                   37.7913               -122.399051               20
# 9                   37.7913               -122.399051               20
# 10        37.78487208436062       -122.40087568759917               22
#
#                                    l_end_station_name l_end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...             37.7787677
# 1                               Dolores St at 15th St             37.7662102
# 2                              Downtown Berkeley BART             37.8703477
# 3        Powell St BART Station (Market St at 5th St)     37.783899357084934
# 4                           Fulton St at Bancroft Way             37.8677892
# 5      San Francisco Caltrain (Townsend St at 4th St)              37.776598
# 6                             Addison St at Fourth St              37.866249
# 7   Yerba Buena Center for the Arts (Howard St at ...      37.78487208436062
# 8     Mechanics Monument Plaza (Market St at Bush St)                37.7913
# 9     Mechanics Monument Plaza (Market St at Bush St)                37.7913
# 10                              Howard St at Beale St              37.789756
#
#          ...       r_start_station_latitude r_start_station_longitude  \
# 0        ...             37.776434819204745       -122.42624402046204
# 1        ...              37.78487208436062       -122.40087568759917
# 2        ...                     37.8703477              -122.2677637
# 3        ...              37.77452040113685        -122.4094493687153
# 4        ...                     37.8688126               -122.258764
# 5        ...                      37.776598               -122.395282
# 6        ...                      37.866249              -122.2993708
# 7        ...              37.78487208436062       -122.40087568759917
# 8        ...                        37.7913               -122.399051
# 9        ...                        37.7913               -122.399051
# 10       ...              37.78487208436062       -122.40087568759917
#
#    r_end_station_id                                 r_end_station_name  \
# 0                43  San Francisco Public Library (Grove St at Hyde...
# 1                96                              Dolores St at 15th St
# 2               245                             Downtown Berkeley BART
# 3                 5       Powell St BART Station (Market St at 5th St)
# 4               247                          Fulton St at Bancroft Way
# 5                30     San Francisco Caltrain (Townsend St at 4th St)
# 6               259                            Addison St at Fourth St
# 7               284  Yerba Buena Center for the Arts (Howard St at ...
# 8                20    Mechanics Monument Plaza (Market St at Bush St)
# 9                20    Mechanics Monument Plaza (Market St at Bush St)
# 10               22                              Howard St at Beale St
#
#    r_end_station_latitude r_end_station_longitude r_bike_id r_user_type  \
# 0              37.7787677            -122.4159292        96    Customer
# 1              37.7662102            -122.4266136        88    Customer
# 2              37.8703477            -122.2677637      1094    Customer
# 3      37.783899357084934     -122.40844488143921      2831    Customer
# 4              37.8677892            -122.2658964      3167  Subscriber
# 5               37.776598             -122.395282      1487    Customer
# 6               37.866249            -122.2993708      3539    Customer
# 7       37.78487208436062     -122.40087568759917      1503    Customer
# 8                 37.7913             -122.399051      3125    Customer
# 9                 37.7913             -122.399051      2543    Customer
# 10              37.789756             -122.394643      3058    Customer
#
#    r_member_birth_year r_member_gender
# 0                 1987            Male
# 1                 1965          Female
# 2
# 3
# 4                 1997          Female
# 5
# 6                 1991          Female
# 7
# 8
# 9
# 10
#
# [11 rows x 30 columns]

# %% [markdown]
# If we look at `r_member_birth_year`, we see that these people were listed as being born in 1886. That's impossible! Now that we've identified outliers and anomalies, we can appropriately clean our data however we like.

# %% [markdown]
# ## 6. Exportation fichier dprep
#
# One of the beautiful features of Azure ML Data Prep is that you only need to write your code once and choose whether to scale up or out; it takes care of figuring out how. To do so, you can export the `.dprep` file you've written tested on a smaller dataset, then run it with your larger dataset. Here, we show how you can export your new package. For a more detailed example on how to execute it on Spark, check out our [New York Taxicab scenario](https://github.com/Microsoft/PendletonDocs/blob/master/Scenarios/NYTaxiCab/01.new_york_taxi.ipynb).

# %%
gobike = gobike.set_name(name="gobike")
package_path = path.join(mkdtemp(), "gobike.dprep")

print("Saving package to: {}".format(package_path))
package = dprep.Package(arg=gobike)
package.save(file_path=package_path)
# Out:
# Saving package to: /tmp/tmpdwtitvt3/gobike.dprep
# Package
#   name: None
#   path: /tmp/tmpdwtitvt3/gobike.dprep
#   dataflows: [
#     Dataflow {
#       name: gobike
#       steps: 3
#     },
#   ]

# %% [markdown]
# ## Want more information?
#
# Congratulations on finishing your introduction to the Azure ML Data Prep SDK! If you'd like more detailed tutorials on how to construct machine learning datasets or dive deeper into all of its functionality, you can find more information in our detailed notebooks [here](https://github.com/Microsoft/PendletonDocs). There, we cover topics including how to:
#
# * Cache your Dataflow to speed up your iterations
# * Add your custom Python transforms
# * Impute missing values
# * Sample your data
# * Reference and link between Dataflows
# * Apply your Dataflow to a new, larger data source
