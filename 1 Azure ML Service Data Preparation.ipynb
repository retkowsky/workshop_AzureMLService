# %% [markdown]
# # 1. Préparation des données avec Azure ML Service

# %% [markdown]
# #### Note: Some features in this Notebook will _not_ work with the Private Preview version of the SDK; it assumes the Public Preview version.
#
# Wonder how you can make the most of the Azure ML Data Prep SDK? In this "Getting Started" guide, we'll showcase a few highlights that make this SDK shine for big datasets where `pandas` and `dplyr` can fall short. Using the [Ford GoBike dataset](https://www.fordgobike.com/system-data) as an example, we'll cover how to build Dataflows that allow you to:

# %% [markdown]
# > https://docs.microsoft.com/fr-fr/python/api/overview/azure/dataprep/intro?view=azure-dataprep-py

# %% [markdown]
# ## 1.1 Paramétrage

# %%
# !pip install --upgrade azureml-dataprep
# Out:
# Collecting azureml-dataprep
#   Downloading https://files.pythonhosted.org/packages/8d/47/b0fb506f7812d64339bc5ec087c6f9ba017a71a82ddaf3e0a448676d55b8/azureml_dataprep-0.5.3-py3-none-any.whl (24.6MB)
#     100% |████████████████████████████████| 24.6MB 164kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml-dataprep) (1.14.6)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<12.0.0,>=11.1.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml-dataprep) (11.1.2)
# Collecting dotnetcore2==2.1.7 (from azureml-dataprep)
#   Downloading https://files.pythonhosted.org/packages/5e/ad/563e291f291ddae9967fc6347b5240e5ee5fdb173c33e0780c30ca8cd4c2/dotnetcore2-2.1.7-py3-none-manylinux1_x86_64.whl (28.7MB)
#     100% |████████████████████████████████| 28.7MB 135kB/s eta 0:00:01    81% |██████████████████████████      | 23.3MB 39.8MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.19.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from azureml-dataprep) (0.22.0)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from dotnetcore2==2.1.7->azureml-dataprep) (1.3.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas>=0.19.2->azureml-dataprep) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas>=0.19.2->azureml-dataprep) (2018.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from python-dateutil>=2->pandas>=0.19.2->azureml-dataprep) (1.11.0)
# Installing collected packages: dotnetcore2, azureml-dataprep
#   Found existing installation: dotnetcore2 2.1.6
#     Uninstalling dotnetcore2-2.1.6:
#       Successfully uninstalled dotnetcore2-2.1.6
#   Found existing installation: azureml-dataprep 0.5.2
#     Uninstalling azureml-dataprep-0.5.2:
#       Successfully uninstalled azureml-dataprep-0.5.2
# Successfully installed azureml-dataprep-0.5.3 dotnetcore2-2.1.7

# %%
import azureml.core
print("SDK Version:", azureml.core.VERSION)
# Out:
# SDK Version: 1.0.2

# %%
from IPython.display import display
from os import path
from tempfile import mkdtemp

import pandas as pd
import azureml.dataprep as dprep

# %% [markdown]
# ## 2. Importation des données
#
# Azure ML Data Prep supports many different file reading formats (i.e. CSV, Excel, Parquet), and also offers the ability to infer column types automatically.

# %%
gobike = dprep.auto_read_file(path="https://dprepdata.blob.core.windows.net/demo/ford_gobike/2017-fordgobike-tripdata.csv")

# %%
gobike.head(10)
# Out:
#    duration_sec              start_time                end_time  \
# 0       80110.0 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1       78800.0 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2       45768.0 2017-12-31 22:45:48.411 2018-01-01 11:28:36.883
# 3       62172.0 2017-12-31 17:31:10.636 2018-01-01 10:47:23.531
# 4       43603.0 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
# 5        9226.0 2017-12-31 22:51:00.918 2018-01-01 01:24:47.166
# 6        4507.0 2017-12-31 23:49:28.422 2018-01-01 01:04:35.619
# 7        4334.0 2017-12-31 23:46:37.196 2018-01-01 00:58:51.211
# 8        4150.0 2017-12-31 23:37:07.548 2018-01-01 00:46:18.308
# 9        4238.0 2017-12-31 23:35:38.145 2018-01-01 00:46:17.053
#
#    start_station_id                                 start_station_name  \
# 0              74.0                              Laguna St at Hayes St
# 1             284.0  Yerba Buena Center for the Arts (Howard St at ...
# 2             245.0                             Downtown Berkeley BART
# 3              60.0                               8th St at Ringold St
# 4             239.0                      Bancroft Way at Telegraph Ave
# 5              30.0     San Francisco Caltrain (Townsend St at 4th St)
# 6             259.0                            Addison St at Fourth St
# 7             284.0  Yerba Buena Center for the Arts (Howard St at ...
# 8              20.0    Mechanics Monument Plaza (Market St at Bush St)
# 9              20.0    Mechanics Monument Plaza (Market St at Bush St)
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.776435              -122.426244            43.0
# 1               37.784872              -122.400876            96.0
# 2               37.870348              -122.267764           245.0
# 3               37.774520              -122.409449             5.0
# 4               37.868813              -122.258764           247.0
# 5               37.776598              -122.395282            30.0
# 6               37.866249              -122.299371           259.0
# 7               37.784872              -122.400876           284.0
# 8               37.791300              -122.399051            20.0
# 9               37.791300              -122.399051            20.0
#
#                                     end_station_name  end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                              Dolores St at 15th St             37.766210
# 2                             Downtown Berkeley BART             37.870348
# 3       Powell St BART Station (Market St at 5th St)             37.783899
# 4                          Fulton St at Bancroft Way             37.867789
# 5     San Francisco Caltrain (Townsend St at 4th St)             37.776598
# 6                            Addison St at Fourth St             37.866249
# 7  Yerba Buena Center for the Arts (Howard St at ...             37.784872
# 8    Mechanics Monument Plaza (Market St at Bush St)             37.791300
# 9    Mechanics Monument Plaza (Market St at Bush St)             37.791300
#
#    end_station_longitude  bike_id   user_type member_birth_year member_gender
# 0            -122.415929     96.0    Customer              1987          Male
# 1            -122.426614     88.0    Customer              1965        Female
# 2            -122.267764   1094.0    Customer              None
# 3            -122.408445   2831.0    Customer              None
# 4            -122.265896   3167.0  Subscriber              1997        Female
# 5            -122.395282   1487.0    Customer              None
# 6            -122.299371   3539.0    Customer              1991        Female
# 7            -122.400876   1503.0    Customer              None
# 8            -122.399051   3125.0    Customer              None
# 9            -122.399051   2543.0    Customer              None

# %% [markdown]
# In order to iterate more quickly, we can take a sample of our data. Later, we can then apply the same transformations to the entire dataset.

# %%
sampled_gobike = gobike.take_sample(probability=0.01, seed=5)

# %% [markdown]
# ## 3. Audit des données
#
# Let's understand what our data looks like. Azure ML Data Prep facilitates this process by offering data profiles that help us glimpse into column types and column summary statistics.

# %%
# Audit sur l'ensemble des données
#gobike.get_profile()

# %%
# Audit sur l'échentillon
sampled_gobike.get_profile()
# Out:
# ColumnProfile
#     name: duration_sec
#     type: FieldType.DECIMAL
#
#     min: 61.0
#     max: 81686.0
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 79.96228571428573
#            1%: 256.0687751581369
#            5%: 250.95744680851064
#           25%: 382.90222335268425
#           50%: 595.0689824408331
#           75%: 936.2761745996927
#           95%: 2273.977068710498
#           99%: 13244.818711350701
#         99.9%: 56320.130514285585
#
#     mean: 1096.7033029612767
#     std: 3332.5228125316357
#     variance: 11105708.296043765
#     skewness: 14.361055989155963
#     kurtosis: 267.0125512989012
#
# ColumnProfile
#     name: start_time
#     type: FieldType.DATE
#
#     min: 2017-06-28 13:48:12.389000+00:00
#     max: 2017-12-31 23:55:09.686000+00:00
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: end_time
#     type: FieldType.DATE
#
#     min: 2017-06-28 14:00:04.925000+00:00
#     max: 2018-01-01 15:12:50.245000+00:00
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: start_station_id
#     type: FieldType.DECIMAL
#
#     min: 3.0
#     max: 340.0
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3.0
#            1%: 11.200501578629172
#            5%: 10.810810810810812
#           25%: 23.478287272214153
#           50%: 66.63621748211912
#           75%: 141.08753501400565
#           95%: 288.4605882352938
#           99%: 323.6796499999999
#         99.9%: 324.75908571428573
#
#     mean: 94.89578587699312
#     std: 86.58862868918469
#     variance: 7497.590618273498
#     skewness: 1.0863386541669284
#     kurtosis: 0.2694157627980025
#
# ColumnProfile
#     name: start_station_name
#     type: FieldType.STRING
#
#     min: 10th Ave at E 15th St
#     max: Yerba Buena Center for the Arts (Howard St at 3rd St)
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: start_station_latitude
#     type: FieldType.DECIMAL
#
#     min: 37.3229796
#     max: 37.88022244590679
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 37.325183680896124
#            1%: 37.76115821491906
#            5%: 37.760927027272736
#           25%: 37.77383106006059
#           50%: 37.78366093167384
#           75%: 37.79538278644787
#           95%: 37.831901055630865
#           99%: 37.869210772374736
#         99.9%: 37.873807204457144
#
#     mean: 37.77152591036754
#     std: 0.08680627534767138
#     variance: 0.0075353294397357395
#     skewness: -4.474982045507375
#     kurtosis: 19.89878207810664
#
# ColumnProfile
#     name: start_station_longitude
#     type: FieldType.DECIMAL
#
#     min: -122.44429260492325
#     max: -121.8766132
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -122.44429260492325
#            1%: -122.42308707826668
#            5%: -122.42320561475309
#           25%: -122.41135477584956
#           50%: -122.39882788070891
#           75%: -122.3911790670108
#           95%: -122.25016614613855
#           99%: -121.88563137264097
#         99.9%: -121.87680204339131
#
#     mean: -122.36382024449563
#     std: 0.1060975221925105
#     variance: 0.011256684215390257
#     skewness: 3.217280197826373
#     kurtosis: 11.148971250166849
#
# ColumnProfile
#     name: end_station_id
#     type: FieldType.DECIMAL
#
#     min: 3.0
#     max: 337.0
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 3.0
#            1%: 9.553211736716895
#            5%: 9.000000000000002
#           25%: 22.819384662404808
#           50%: 65.76639928136332
#           75%: 137.80934956794974
#           95%: 290.3268164671148
#           99%: 323.87758064516123
#         99.9%: 324.75908571428573
#
#     mean: 93.37680334092656
#     std: 86.30597703403608
#     variance: 7448.721671799563
#     skewness: 1.1112675033371304
#     kurtosis: 0.3306812473352827
#
# ColumnProfile
#     name: end_station_name
#     type: FieldType.STRING
#
#     min: 10th Ave at E 15th St
#     max: Yerba Buena Center for the Arts (Howard St at 3rd St)
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: end_station_latitude
#     type: FieldType.DECIMAL
#
#     min: 37.3229796
#     max: 37.8740141
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 37.32556625008
#            1%: 37.76102519714343
#            5%: 37.76063178275862
#           25%: 37.774454168063954
#           50%: 37.78343417086936
#           75%: 37.795401690945326
#           95%: 37.83002184282974
#           99%: 37.86845154737255
#         99.9%: 37.87314898656177
#
#     mean: 37.771323969385996
#     std: 0.08680616697004766
#     variance: 0.007535310624031792
#     skewness: -4.507611732549
#     kurtosis: 20.077291553023525
#
# ColumnProfile
#     name: end_station_longitude
#     type: FieldType.DECIMAL
#
#     min: -122.44429260492325
#     max: -121.8759263
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -122.44429260492325
#            1%: -122.42145654539468
#            5%: -122.4214885557377
#           25%: -122.41066619598764
#           50%: -122.3987303728655
#           75%: -122.39110855865363
#           95%: -122.249013640439
#           99%: -121.88600928414358
#         99.9%: -121.87689376448
#
#     mean: -122.36329141256938
#     std: 0.10563559750051475
#     variance: 0.01115887945929076
#     skewness: 3.235970241186922
#     kurtosis: 11.253624434695375
#
# ColumnProfile
#     name: bike_id
#     type: FieldType.DECIMAL
#
#     min: 12.0
#     max: 3720.0
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 16.854690909090905
#            1%: 309.23396382428945
#            5%: 278.67999999999995
#           25%: 799.3935259794388
#           50%: 1735.4084996636016
#           75%: 2520.677160696681
#           95%: 3104.473873873874
#           99%: 3388.8537499999998
#         99.9%: 3680.5696
#
#     mean: 1676.6442672741077
#     std: 968.3571002383821
#     variance: 937715.4735820881
#     skewness: -0.07131081870602919
#     kurtosis: -1.2218428204744065
#
# ColumnProfile
#     name: user_type
#     type: FieldType.STRING
#
#     min: Customer
#     max: Subscriber
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile
#     name: member_birth_year
#     type: FieldType.DECIMAL
#
#     min: 1924.0
#     max: 1999.0
#     count: 5268.0
#     missing_count: 654.0
#     not_missing_count: 4614.0
#     percent_missing: 0.12414578587699317
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1941.6947076923077
#            1%: 1965.7132063882063
#            5%: 1965.4324324324325
#           25%: 1974.5106809561182
#           50%: 1982.8634615384615
#           75%: 1987.990478515625
#           95%: 1993.4886674968866
#           99%: 1996.6815217391302
#         99.9%: 1999.0
#
#     mean: 1980.59861291721
#     std: 10.067371483842622
#     variance: 101.35196859368762
#     skewness: -0.857213350460693
#     kurtosis: 0.4982776322261766
#
# ColumnProfile
#     name: member_gender
#     type: FieldType.STRING
#
#     min:
#     max: Other
#     count: 5268.0
#     missing_count: 0.0
#     not_missing_count: 5268.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 652.0

# %% [markdown]
# It appears that we have quite a few missing values in `member_birth_year`. We also immediately see that we have some empty strings in our `member_gender` column. With the data profiler, we can quickly do a sanity check on our dataset and see where we might need to start data cleaning.

# %% [markdown]
# ## 4. Transformation des données par l'exemple
#
# Azure ML Data Prep comes with additional "smart" transforms created by Microsoft Research. Here, we'll look at how you can derive a new column by providing examples of input-output pairs. Rather than explicitly using regular expressions to extract dates or hours from datetimes, we can provide examples for Azure ML Data Prep to learn what the pattern is. In fact, these smart transformations can also handle more complex derivations like inferring the day of the week from datetimes.

# %%
sgb_derived = sampled_gobike\
    .to_string(
        columns=['start_time', 'end_time']
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='date',
        example_data=[('2017-12-31 16:57:39.6540', '2017-12-31'), ('2017-12-31 16:57:39', '2017-12-31')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='hour',
        example_data=[('2017-12-31 16:57:39.6540', '16')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='wday',
        example_data=[('2017-12-31 16:57:39.6540', 'Sunday')]
    )\
    .derive_column_by_example(
        source_columns='start_time',
        new_column_name='day',
        example_data=[('2017-12-31 16:57:39.6540', '31')]
    )\
      .derive_column_by_example(
        source_columns='start_time',
        new_column_name='month',
        example_data=[('2017-12-31 16:57:39.6540', '12')]
    )

# %%
sgb_derived.filter(dprep.col('wday') != 'Sunday').head(11)
# Out:
#     duration_sec                  start_time month day      wday hour  \
# 0          572.0  2017-12-30 18:19:05.731000    12  30  Saturday   18
# 1          821.0  2017-12-30 18:13:05.124000    12  30  Saturday   18
# 2         2789.0  2017-12-30 15:52:21.222000    12  30  Saturday   15
# 3         1380.0  2017-12-30 16:07:44.108000    12  30  Saturday   16
# 4          198.0  2017-12-30 16:23:49.031000    12  30  Saturday   16
# 5          463.0  2017-12-30 15:43:11.552000    12  30  Saturday   15
# 6         1334.0  2017-12-30 14:21:05.333000    12  30  Saturday   14
# 7          603.0  2017-12-30 14:15:40.583000    12  30  Saturday   14
# 8          858.0  2017-12-30 13:52:14.755000    12  30  Saturday   13
# 9         1720.0  2017-12-30 12:13:24.174000    12  30  Saturday   12
# 10         370.0  2017-12-30 11:45:33.278000    12  30  Saturday   11
#
#           date                    end_time  start_station_id  \
# 0   2017-12-30  2017-12-30 18:28:37.825000             323.0
# 1   2017-12-30  2017-12-30 18:26:46.365000             317.0
# 2   2017-12-30  2017-12-30 16:38:50.427000             121.0
# 3   2017-12-30  2017-12-30 16:30:44.901000             239.0
# 4   2017-12-30  2017-12-30 16:27:07.723000              76.0
# 5   2017-12-30  2017-12-30 15:50:55.004000             324.0
# 6   2017-12-30  2017-12-30 14:43:20.036000              85.0
# 7   2017-12-30  2017-12-30 14:25:43.785000               6.0
# 8   2017-12-30  2017-12-30 14:06:32.916000              60.0
# 9   2017-12-30  2017-12-30 12:42:04.366000               6.0
# 10  2017-12-30  2017-12-30 11:51:44.182000             197.0
#
#                      start_station_name  start_station_latitude  \
# 0                    Broadway at Kearny               37.798014
# 1             San Salvador St at 9th St               37.333955
# 2                    Mission Playground               37.759210
# 3         Bancroft Way at Telegraph Ave               37.868813
# 4            McCoppin St at Valencia St               37.771662
# 5   Union Square (Powell St at Post St)               37.788300
# 6               Church St at Duboce Ave               37.770083
# 7         The Embarcadero at Sansome St               37.804770
# 8                  8th St at Ringold St               37.774520
# 9         The Embarcadero at Sansome St               37.804770
# 10          El Embarcadero at Grand Ave               37.808848
#
#     start_station_longitude  end_station_id  \
# 0               -122.405950            15.0
# 1               -121.877349           304.0
# 2               -122.421339           120.0
# 3               -122.258764           241.0
# 4               -122.422423            76.0
# 5               -122.408531            44.0
# 6               -122.429156            17.0
# 7               -122.403234           323.0
# 8               -122.409449            36.0
# 9               -122.403234            99.0
# 10              -122.249680           200.0
#
#                                      end_station_name  end_station_latitude  \
# 0   San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 1                                Jackson St at 5th St             37.348759
# 2                                Mission Dolores Park             37.761420
# 3                                  Ashby BART Station             37.852477
# 4                          McCoppin St at Valencia St             37.771662
# 5   Civic Center/UN Plaza BART Station (Market St ...             37.781074
# 6    Embarcadero BART Station (Beale St at Market St)             37.792251
# 7                                  Broadway at Kearny             37.798014
# 8                                 Folsom St at 3rd St             37.783830
# 9                                Folsom St at 15th St             37.767037
# 10                               2nd Ave at E 18th St             37.800214
#
#     end_station_longitude  bike_id   user_type member_birth_year member_gender
# 0             -122.394203   3033.0    Customer              1996          Male
# 1             -121.894798   2533.0  Subscriber              1970          Male
# 2             -122.426435   1837.0    Customer              None
# 3             -122.270213   1297.0    Customer              None
# 4             -122.422423    364.0    Customer              None
# 5             -122.411738    762.0  Subscriber              1991        Female
# 6             -122.397086    974.0    Customer              None
# 7             -122.405950   2359.0    Customer              None
# 8             -122.398870    276.0    Customer              None
# 9             -122.415442    617.0    Customer              1972        Female
# 10            -122.253810   1545.0  Subscriber              1974        Female

# %% [markdown]
# We can also filter on other column types; let's take a peek at rides that lasted over 5 hours.

# %%
sgb_derived.filter(dprep.col('duration_sec') > (60 * 60 * 5)).head(11)
# Out:
#     duration_sec                  start_time month day       wday hour  \
# 0        80110.0  2017-12-31 16:57:39.654000    12  31     Sunday   16
# 1        19738.0  2017-12-27 10:08:32.337000    12  27  Wednesday   10
# 2        22442.0  2017-12-15 12:24:44.370000    12  15     Friday   12
# 3        27433.0  2017-11-06 08:33:58.415000    11  06     Monday   08
# 4        28467.0  2017-10-25 22:59:12.266000    10  25  Wednesday   22
# 5        22532.0  2017-10-05 18:08:47.166000    10  05   Thursday   18
# 6        21050.0  2017-10-03 08:59:55.957000    10  03    Tuesday   08
# 7        81686.0  2017-09-30 18:12:21.667000    09  30   Saturday   18
# 8        29494.0  2017-09-23 11:08:56.665000    09  23   Saturday   11
# 9        76987.0  2017-09-20 09:22:14.400000    09  20  Wednesday   09
# 10       23040.0  2017-09-18 10:11:18.370000    09  18     Monday   10
#
#           date                    end_time  start_station_id  \
# 0   2017-12-31  2018-01-01 15:12:50.245000              74.0
# 1   2017-12-27  2017-12-27 15:37:31.208000              95.0
# 2   2017-12-15  2017-12-15 18:38:47.010000             275.0
# 3   2017-11-06  2017-11-06 16:11:11.583000              75.0
# 4   2017-10-25  2017-10-26 06:53:39.765000             108.0
# 5   2017-10-05  2017-10-06 00:24:19.285000             323.0
# 6   2017-10-03  2017-10-03 14:50:46.614000              24.0
# 7   2017-09-30  2017-10-01 16:53:48.361000               6.0
# 8   2017-09-23  2017-09-23 19:20:31.620000               4.0
# 9   2017-09-20  2017-09-21 06:45:21.472000             164.0
# 10  2017-09-18  2017-09-18 16:35:18.664000              58.0
#
#                start_station_name  start_station_latitude  \
# 0           Laguna St at Hayes St               37.776435
# 1           Sanchez St at 15th St               37.766219
# 2             Julian St at 6th St               37.342997
# 3        Market St at Franklin St               37.773793
# 4            16th St Mission BART               37.764710
# 5              Broadway at Kearny               37.798014
# 6           Spear St at Folsom St               37.789677
# 7   The Embarcadero at Sansome St               37.804770
# 8     Cyril Magnin St at Ellis St               37.785881
# 9    Isabella St at San Pablo Ave               37.814988
# 10           Market St at 10th St               37.776619
#
#     start_station_longitude  end_station_id  \
# 0               -122.426244            43.0
# 1               -122.431060            31.0
# 2               -121.888889           278.0
# 3               -122.421239            58.0
# 4               -122.419957           119.0
# 5               -122.405950             4.0
# 6               -122.390428            24.0
# 7               -122.403234            81.0
# 8               -122.408915             6.0
# 9               -122.274844           164.0
# 10              -122.417385            15.0
#
#                                      end_station_name  end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                          Raymond Kimbell Playground             37.783813
# 2                              The Alameda at Bush St             37.331932
# 3                                Market St at 10th St             37.776619
# 4                                   18th St at Noe St             37.761047
# 5                         Cyril Magnin St at Ellis St             37.785881
# 6                               Spear St at Folsom St             37.789677
# 7                                  Berry St at 4th St             37.775880
# 8                       The Embarcadero at Sansome St             37.804770
# 9                        Isabella St at San Pablo Ave             37.814988
# 10  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
#
#     end_station_longitude  bike_id   user_type member_birth_year member_gender
# 0             -122.415929     96.0    Customer              1987          Male
# 1             -122.434559    931.0    Customer              None
# 2             -121.904888   1872.0  Subscriber              1983          Male
# 3             -122.417385   2291.0    Customer              None
# 4             -122.432642   2423.0  Subscriber              1973          Male
# 5             -122.408915    307.0  Subscriber              1987          Male
# 6             -122.390428   2818.0    Customer              None
# 7             -122.393170   2371.0    Customer              None
# 8             -122.403234   2210.0    Customer              None
# 9             -122.274844    554.0    Customer              1977        Female
# 10            -122.394203   2423.0    Customer              None

# %% [markdown]
# ## 5. Transformation des données
#
# In addition to "smart" transformations, Azure ML Data Prep also supports many common data science transforms familiar to other industry-standard data science libraries. Here, we'll explore the ability to `summarize` and `replace`. We'll also get to use `join` when we handle assertions.
#
# #### Agrégation

# %% [markdown]
# Azure Data Prep also makes it easy to append this output of `summarize` to the original table based on the grouping variable.

# %%
sgb_appended = sgb_derived\
    .summarize(
        summary_columns=[
            dprep\
                .SummaryColumnsValue(
                    column_id='duration_sec', 
                    summary_column_name='duration_sec_mean', 
                    summary_function=dprep.SummaryFunction.MEAN
                )
        ],
        group_by_columns=['date'],
        join_back=True
    )
sgb_appended.head(11)
# Out:
#     duration_sec                  start_time month day    wday hour  \
# 0        80110.0  2017-12-31 16:57:39.654000    12  31  Sunday   16
# 1         1397.0  2017-12-31 23:55:09.686000    12  31  Sunday   23
# 2         2511.0  2017-12-31 22:58:26.524000    12  31  Sunday   22
# 3          901.0  2017-12-31 22:17:39.910000    12  31  Sunday   22
# 4          853.0  2017-12-31 21:22:37.643000    12  31  Sunday   21
# 5          189.0  2017-12-31 20:48:37.492000    12  31  Sunday   20
# 6         1208.0  2017-12-31 19:56:43.394000    12  31  Sunday   19
# 7          426.0  2017-12-31 17:11:48.331000    12  31  Sunday   17
# 8          962.0  2017-12-31 16:57:20.930000    12  31  Sunday   16
# 9          204.0  2017-12-31 15:26:41.663000    12  31  Sunday   15
# 10         819.0  2017-12-31 15:06:20.173000    12  31  Sunday   15
#
#           date                    end_time  start_station_id  \
# 0   2017-12-31  2018-01-01 15:12:50.245000              74.0
# 1   2017-12-31  2018-01-01 00:18:26.721000              78.0
# 2   2017-12-31  2017-12-31 23:40:17.987000              30.0
# 3   2017-12-31  2017-12-31 22:32:41.630000              66.0
# 4   2017-12-31  2017-12-31 21:36:51.179000              14.0
# 5   2017-12-31  2017-12-31 20:51:46.658000              37.0
# 6   2017-12-31  2017-12-31 20:16:51.551000              13.0
# 7   2017-12-31  2017-12-31 17:18:55.001000             123.0
# 8   2017-12-31  2017-12-31 17:13:23.560000             176.0
# 9   2017-12-31  2017-12-31 15:30:06.146000              86.0
# 10  2017-12-31  2017-12-31 15:19:59.864000              81.0
#
#                                 start_station_name        ...         \
# 0                            Laguna St at Hayes St        ...
# 1                              Folsom St at 9th St        ...
# 2   San Francisco Caltrain (Townsend St at 4th St)        ...
# 3                            3rd St at Townsend St        ...
# 4                            Clay St at Battery St        ...
# 5                              2nd St at Folsom St        ...
# 6                   Commercial St at Montgomery St        ...
# 7                             Folsom St at 19th St        ...
# 8                           MacArthur BART Station        ...
# 9                          Market St at Dolores St        ...
# 10                              Berry St at 4th St        ...
#
#     start_station_longitude  end_station_id  \
# 0               -122.426244            43.0
# 1               -122.411647            15.0
# 2               -122.395282             6.0
# 3               -122.392741            23.0
# 4               -122.399970             8.0
# 5               -122.395936            48.0
# 6               -122.402923             6.0
# 7               -122.414817           134.0
# 8               -122.266315           231.0
# 9               -122.426826            95.0
# 10              -122.393170            15.0
#
#                                      end_station_name end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...            37.778768
# 1   San Francisco Ferry Building (Harry Bridges Pl...            37.795392
# 2                       The Embarcadero at Sansome St            37.804770
# 3                       The Embarcadero at Steuart St            37.791464
# 4                       The Embarcadero at Vallejo St            37.799953
# 5                                 2nd St at S Park St            37.782411
# 6                       The Embarcadero at Sansome St            37.804770
# 7                              Valencia St at 24th St            37.752428
# 8                               14th St at Filbert St            37.808750
# 9                               Sanchez St at 15th St            37.766219
# 10  San Francisco Ferry Building (Harry Bridges Pl...            37.795392
#
#     end_station_longitude  bike_id   user_type member_birth_year  \
# 0             -122.415929     96.0    Customer            1987.0
# 1             -122.394203   1667.0    Customer               NaN
# 2             -122.403234   3329.0    Customer               NaN
# 3             -122.391034   3569.0    Customer               NaN
# 4             -122.398525    101.0    Customer               NaN
# 5             -122.392706   1056.0    Customer            1988.0
# 6             -122.403234   2736.0  Subscriber            1994.0
# 7             -122.420628   2256.0  Subscriber            1991.0
# 8             -122.283282    305.0    Customer               NaN
# 9             -122.431060   2183.0  Subscriber            1992.0
# 10            -122.394203    464.0    Customer            1994.0
#
#     member_gender duration_sec_mean
# 0            Male       5309.111111
# 1                       5309.111111
# 2                       5309.111111
# 3                       5309.111111
# 4                       5309.111111
# 5            Male       5309.111111
# 6            Male       5309.111111
# 7            Male       5309.111111
# 8                       5309.111111
# 9            Male       5309.111111
# 10         Female       5309.111111
#
# [11 rows x 21 columns]

# %% [markdown]
# #### Remplacement des valeurs manquantes
#
# Recall that our `member_gender` column had empty strings that stood in place of `None`. Let's use our `replace` function to properly recode them as `None`s.

# %%
sgb_replaced = sampled_gobike.replace_na(columns=['member_gender'])
sgb_replaced.head(11)
# Out:
#     duration_sec              start_time                end_time  \
# 0        80110.0 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1         1397.0 2017-12-31 23:55:09.686 2018-01-01 00:18:26.721
# 2         2511.0 2017-12-31 22:58:26.524 2017-12-31 23:40:17.987
# 3          901.0 2017-12-31 22:17:39.910 2017-12-31 22:32:41.630
# 4          853.0 2017-12-31 21:22:37.643 2017-12-31 21:36:51.179
# 5          189.0 2017-12-31 20:48:37.492 2017-12-31 20:51:46.658
# 6         1208.0 2017-12-31 19:56:43.394 2017-12-31 20:16:51.551
# 7          426.0 2017-12-31 17:11:48.331 2017-12-31 17:18:55.001
# 8          962.0 2017-12-31 16:57:20.930 2017-12-31 17:13:23.560
# 9          204.0 2017-12-31 15:26:41.663 2017-12-31 15:30:06.146
# 10         819.0 2017-12-31 15:06:20.173 2017-12-31 15:19:59.864
#
#     start_station_id                              start_station_name  \
# 0               74.0                           Laguna St at Hayes St
# 1               78.0                             Folsom St at 9th St
# 2               30.0  San Francisco Caltrain (Townsend St at 4th St)
# 3               66.0                           3rd St at Townsend St
# 4               14.0                           Clay St at Battery St
# 5               37.0                             2nd St at Folsom St
# 6               13.0                  Commercial St at Montgomery St
# 7              123.0                            Folsom St at 19th St
# 8              176.0                          MacArthur BART Station
# 9               86.0                         Market St at Dolores St
# 10              81.0                              Berry St at 4th St
#
#     start_station_latitude  start_station_longitude  end_station_id  \
# 0                37.776435              -122.426244            43.0
# 1                37.773717              -122.411647            15.0
# 2                37.776598              -122.395282             6.0
# 3                37.778742              -122.392741            23.0
# 4                37.795001              -122.399970             8.0
# 5                37.785000              -122.395936            48.0
# 6                37.794231              -122.402923             6.0
# 7                37.760594              -122.414817           134.0
# 8                37.828410              -122.266315           231.0
# 9                37.769305              -122.426826            95.0
# 10               37.775880              -122.393170            15.0
#
#                                      end_station_name  end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...             37.778768
# 1   San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 2                       The Embarcadero at Sansome St             37.804770
# 3                       The Embarcadero at Steuart St             37.791464
# 4                       The Embarcadero at Vallejo St             37.799953
# 5                                 2nd St at S Park St             37.782411
# 6                       The Embarcadero at Sansome St             37.804770
# 7                              Valencia St at 24th St             37.752428
# 8                               14th St at Filbert St             37.808750
# 9                               Sanchez St at 15th St             37.766219
# 10  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
#
#     end_station_longitude  bike_id   user_type  member_birth_year  \
# 0             -122.415929     96.0    Customer             1987.0
# 1             -122.394203   1667.0    Customer                NaN
# 2             -122.403234   3329.0    Customer                NaN
# 3             -122.391034   3569.0    Customer                NaN
# 4             -122.398525    101.0    Customer                NaN
# 5             -122.392706   1056.0    Customer             1988.0
# 6             -122.403234   2736.0  Subscriber             1994.0
# 7             -122.420628   2256.0  Subscriber             1991.0
# 8             -122.283282    305.0    Customer                NaN
# 9             -122.431060   2183.0  Subscriber             1992.0
# 10            -122.394203    464.0    Customer             1994.0
#
#    member_gender
# 0           Male
# 1           None
# 2           None
# 3           None
# 4           None
# 5           Male
# 6           Male
# 7           Male
# 8           None
# 9           Male
# 10        Female

# %% [markdown]
# ## Assert on invalid data

# %%
gb_asserted = gobike\
    .assert_value(
        columns='member_birth_year', 
        expression=dprep.f_or(dprep.value.is_null(), dprep.value <= 1920),
        error_code='InvalidDate'
    )

# %% [markdown]
# Now, we can filter to see what caused the errors above:

# %%
gb_errors = gb_asserted.filter(dprep.col('member_birth_year').is_error())
gb_errors.head(5)
# Out:
#    duration_sec              start_time                end_time  \
# 0       80110.0 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1       78800.0 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2       43603.0 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
# 3        4507.0 2017-12-31 23:49:28.422 2018-01-01 01:04:35.619
# 4        2183.0 2017-12-31 23:52:55.581 2018-01-01 00:29:18.743
#
#    start_station_id                                 start_station_name  \
# 0              74.0                              Laguna St at Hayes St
# 1             284.0  Yerba Buena Center for the Arts (Howard St at ...
# 2             239.0                      Bancroft Way at Telegraph Ave
# 3             259.0                            Addison St at Fourth St
# 4              67.0  San Francisco Caltrain Station 2  (Townsend St...
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.776435              -122.426244            43.0
# 1               37.784872              -122.400876            96.0
# 2               37.868813              -122.258764           247.0
# 3               37.866249              -122.299371           259.0
# 4               37.776639              -122.395526            24.0
#
#                                     end_station_name  end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                              Dolores St at 15th St             37.766210
# 2                          Fulton St at Bancroft Way             37.867789
# 3                            Addison St at Fourth St             37.866249
# 4                              Spear St at Folsom St             37.789677
#
#    end_station_longitude  bike_id   user_type  \
# 0            -122.415929     96.0    Customer
# 1            -122.426614     88.0    Customer
# 2            -122.265896   3167.0  Subscriber
# 3            -122.299371   3539.0    Customer
# 4            -122.390428   2311.0  Subscriber
#
#                                    member_birth_year member_gender
# 0  azureml.dataprep.native.DataPrepError("'Invali...          Male
# 1  azureml.dataprep.native.DataPrepError("'Invali...        Female
# 2  azureml.dataprep.native.DataPrepError("'Invali...        Female
# 3  azureml.dataprep.native.DataPrepError("'Invali...        Female
# 4  azureml.dataprep.native.DataPrepError("'Invali...          Male

# %% [markdown]
# #### Jointure
# But what were the original values? Let's use `join` to figure out what the values were that caused our assert to throw an error.

# %%
gb_errors.join(
    left_dataflow=gb_errors,
    right_dataflow=gobike,
    join_key_pairs=[
        ('duration_sec', 'duration_sec'),
        ('start_station_id', 'start_station_id'),
        ('bike_id', 'bike_id')
    ]
).head(11)
# Out:
#     l_duration_sec            l_start_time              l_end_time  \
# 0          80110.0 2017-12-31 16:57:39.654 2018-01-01 15:12:50.245
# 1          78800.0 2017-12-31 15:56:34.842 2018-01-01 13:49:55.617
# 2          43603.0 2017-12-31 14:23:14.001 2018-01-01 02:29:57.571
# 3           4507.0 2017-12-31 23:49:28.422 2018-01-01 01:04:35.619
# 4           2183.0 2017-12-31 23:52:55.581 2018-01-01 00:29:18.743
# 5           2170.0 2017-12-31 23:52:55.937 2018-01-01 00:29:06.924
# 6           1544.0 2017-12-31 23:53:38.943 2018-01-01 00:19:23.047
# 7           1474.0 2017-12-31 23:54:40.146 2018-01-01 00:19:14.351
# 8           1532.0 2017-12-31 23:52:49.497 2018-01-01 00:18:21.953
# 9           1216.0 2017-12-31 23:46:33.993 2018-01-01 00:06:50.058
# 10           386.0 2017-12-31 23:59:01.261 2018-01-01 00:05:27.809
#
#     l_start_station_id                               l_start_station_name  \
# 0                 74.0                              Laguna St at Hayes St
# 1                284.0  Yerba Buena Center for the Arts (Howard St at ...
# 2                239.0                      Bancroft Way at Telegraph Ave
# 3                259.0                            Addison St at Fourth St
# 4                 67.0  San Francisco Caltrain Station 2  (Townsend St...
# 5                 67.0  San Francisco Caltrain Station 2  (Townsend St...
# 6                 14.0                              Clay St at Battery St
# 7                 14.0                              Clay St at Battery St
# 8                 78.0                                Folsom St at 9th St
# 9                  4.0                        Cyril Magnin St at Ellis St
# 10               317.0                          San Salvador St at 9th St
#
#     l_start_station_latitude  l_start_station_longitude  l_end_station_id  \
# 0                  37.776435                -122.426244              43.0
# 1                  37.784872                -122.400876              96.0
# 2                  37.868813                -122.258764             247.0
# 3                  37.866249                -122.299371             259.0
# 4                  37.776639                -122.395526              24.0
# 5                  37.776639                -122.395526              24.0
# 6                  37.795001                -122.399970              27.0
# 7                  37.795001                -122.399970              27.0
# 8                  37.773717                -122.411647              15.0
# 9                  37.785881                -122.408915             123.0
# 10                 37.333955                -121.877349             296.0
#
#                                    l_end_station_name  l_end_station_latitude  \
# 0   San Francisco Public Library (Grove St at Hyde...               37.778768
# 1                               Dolores St at 15th St               37.766210
# 2                           Fulton St at Bancroft Way               37.867789
# 3                             Addison St at Fourth St               37.866249
# 4                               Spear St at Folsom St               37.789677
# 5                               Spear St at Folsom St               37.789677
# 6                             Beale St at Harrison St               37.788059
# 7                             Beale St at Harrison St               37.788059
# 8   San Francisco Ferry Building (Harry Bridges Pl...               37.795392
# 9                                Folsom St at 19th St               37.760594
# 10                              5th St at Virginia St               37.325998
#
#          ...        r_start_station_latitude  r_start_station_longitude  \
# 0        ...                       37.776435                -122.426244
# 1        ...                       37.784872                -122.400876
# 2        ...                       37.868813                -122.258764
# 3        ...                       37.866249                -122.299371
# 4        ...                       37.776639                -122.395526
# 5        ...                       37.776639                -122.395526
# 6        ...                       37.795001                -122.399970
# 7        ...                       37.795001                -122.399970
# 8        ...                       37.773717                -122.411647
# 9        ...                       37.785881                -122.408915
# 10       ...                       37.333955                -121.877349
#
#    r_end_station_id                                 r_end_station_name  \
# 0              43.0  San Francisco Public Library (Grove St at Hyde...
# 1              96.0                              Dolores St at 15th St
# 2             247.0                          Fulton St at Bancroft Way
# 3             259.0                            Addison St at Fourth St
# 4              24.0                              Spear St at Folsom St
# 5              24.0                              Spear St at Folsom St
# 6              27.0                            Beale St at Harrison St
# 7              27.0                            Beale St at Harrison St
# 8              15.0  San Francisco Ferry Building (Harry Bridges Pl...
# 9             123.0                               Folsom St at 19th St
# 10            296.0                              5th St at Virginia St
#
#    r_end_station_latitude  r_end_station_longitude r_bike_id r_user_type  \
# 0               37.778768              -122.415929      96.0    Customer
# 1               37.766210              -122.426614      88.0    Customer
# 2               37.867789              -122.265896    3167.0  Subscriber
# 3               37.866249              -122.299371    3539.0    Customer
# 4               37.789677              -122.390428    2311.0  Subscriber
# 5               37.789677              -122.390428    3717.0  Subscriber
# 6               37.788059              -122.391865     558.0  Subscriber
# 7               37.788059              -122.391865    3646.0  Subscriber
# 8               37.795392              -122.394203    3114.0  Subscriber
# 9               37.760594              -122.414817    1473.0  Subscriber
# 10              37.325998              -121.877120    1603.0  Subscriber
#
#     r_member_birth_year r_member_gender
# 0                1987.0            Male
# 1                1965.0          Female
# 2                1997.0          Female
# 3                1991.0          Female
# 4                1990.0            Male
# 5                1990.0            Male
# 6                1980.0          Female
# 7                1979.0            Male
# 8                1988.0           Other
# 9                1971.0            Male
# 10               1992.0            Male
#
# [11 rows x 30 columns]

# %% [markdown]
# If we look at `r_member_birth_year`, we see that these people were listed as being born in 1886. That's impossible! Now that we've identified outliers and anomalies, we can appropriately clean our data however we like.

# %% [markdown]
# ## 6. Exportation fichier dprep
#
# One of the beautiful features of Azure ML Data Prep is that you only need to write your code once and choose whether to scale up or out; it takes care of figuring out how. To do so, you can export the `.dprep` file you've written tested on a smaller dataset, then run it with your larger dataset. Here, we show how you can export your new package. For a more detailed example on how to execute it on Spark, check out our [New York Taxicab scenario](https://github.com/Microsoft/PendletonDocs/blob/master/Scenarios/NYTaxiCab/01.new_york_taxi.ipynb).

# %%
gobike = gobike.set_name(name="gobike")
package_path = path.join(mkdtemp(), "gobike.dprep")

print("Saving package to: {}".format(package_path))
package = dprep.Package(arg=gobike)
package.save(file_path=package_path)
# Out:
# Saving package to: /tmp/tmp54l1rjoe/gobike.dprep
# Package
#   name: None
#   path: /tmp/tmp54l1rjoe/gobike.dprep
#   dataflows: [
#     Dataflow {
#       name: gobike
#       steps: 4
#     },
#   ]

# %% [markdown]
# On charge le package

# %%
package = dprep.Package.open("/tmp/tmp54l1rjoe/gobike.dprep")
dataflow_list = package.dataflows

# %% [markdown]
# > Documentation
# https://docs.microsoft.com/fr-fr/python/api/overview/azure/dataprep/intro?view=azure-dataprep-py

# %% [markdown]
# ## Want more information?
#
# Congratulations on finishing your introduction to the Azure ML Data Prep SDK! If you'd like more detailed tutorials on how to construct machine learning datasets or dive deeper into all of its functionality, you can find more information in our detailed notebooks [here](https://github.com/Microsoft/PendletonDocs). There, we cover topics including how to:
#
# * Cache your Dataflow to speed up your iterations
# * Add your custom Python transforms
# * Impute missing values
# * Sample your data
# * Reference and link between Dataflows
# * Apply your Dataflow to a new, larger data source
